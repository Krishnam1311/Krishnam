# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Krishnam Sanjaykumar Kansara**
# Data Scientist

# %% [markdown]
# *I am interested in data science because I love to do statistical/data analysis as well as to deploy machine learning models and statistics.*

# %% [markdown]
# ### The code below is supposed to print the statement.

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ~strike text~
# <strike>strike text</strike>
# <del>strike text<del>
#
# - AI
#      - ML
#
# 1. Data Scientist
# 2. Data Analyst
# 3. Business Analyst
